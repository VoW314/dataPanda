# %%
#Analytics and path imports
import os #good for working with files
import pathlib #find path
import re #all importable objects are compiled regular expressions
import pandas as pd #data analytics library

#Dash imports
import plotly.express as px #maps
import dash #the main library
import dash_table
import dash_core_components as dcc #dash components
import plotly.graph_objs as go
import dash_html_components as html #html dash components

VAplan = pd.read_csv('files/VAplan3.csv')
VAplan = VAplan[pd.notnull(VAplan['Risk'])]
VAplan
# Out:
#           County  Number of Students  \
# 0       Accomack              5171.0
# 1     Albermarle             14435.0
# 2     Alexandria             16307.0
# 3      Alleghany              2024.0
# 4         Amelia              1731.0
# ..           ...                 ...
# 128  Willamsburg             11805.0
# 129   Winchester              4392.0
# 130         Wise              5632.0
# 131        Wythe              3982.0
# 132         York             13184.0
#
#                                 Elementary school Plan  \
# 0    2 days in-school (50% students) and 3 days vir...
# 1                                         All virtual
# 2                                          All Virtual
# 3    2 days in-school (50% students) and 3 days vir...
# 4      All students 4 days in-school and 1 day virtual
# ..                                                 ...
# 128                                        All virtual
# 129  2 days in-school (50% students) and 3 days vir...
# 130  2 days in-school (50% students) and 3 days vir...
# 131                                        All virtual
# 132                                        All Virtual
#
#                                  Secondary School Plan      Risk
# 0    2 days in-school (50% students) and 3 days vir...  Moderate
# 1                                         All virtual        Low
# 2                                          All Virtual       Low
# 3    2 days in-school (50% students) and 3 days vir...  Moderate
# 4    2 days in-school (50% students) and 3 days vir...      High
# ..                                                 ...       ...
# 128                                        All virtual       Low
# 129  2 days in-school (50% students) and 3 days vir...      High
# 130  2 days in-school (50% students) and 3 days vir...  Moderate
# 131                                        All virtual       Low
# 132                                        All Virtual       Low
#
# [132 rows x 5 columns]

# %%
VAplan = pd.DataFrame(VAplan, columns =['County', 'Number of Students', 'Elementary School Plan', 'Secondary School Plan', 'Risk'])
#High Risk
#highRk = VAplan[ VAplan['Risk'] == "High"]
#highRk.to_csv('files/dsplit/Highrisk.csv')

#low Risk
#lowRk = VAplan[ VAplan['Risk'] == "Low"]
#lowRk.to_csv('files/dsplit/Lowrisk.csv')

#moderate Risk
#modRk = VAplan[ VAplan['Risk'] == "Moderate"]
#modRk.to_csv('files/dsplit/Modrisk.csv')

#still planning
#spRk = VAplan[ VAplan['Risk'] == "still planning"]
#spRk.to_csv('files/dsplit/sp.csv')

#only special needs are at risk as they come into school 
#osn = VAplan [ VAplan['Risk'] == "only special need in-person"]
#osn.to_csv('files/dsplit/osn.csv')
VAplan
# Out:
#           County  Number of Students  Elementary School Plan  \
# 0       Accomack              5171.0                     NaN
# 1     Albermarle             14435.0                     NaN
# 2     Alexandria             16307.0                     NaN
# 3      Alleghany              2024.0                     NaN
# 4         Amelia              1731.0                     NaN
# ..           ...                 ...                     ...
# 128  Willamsburg             11805.0                     NaN
# 129   Winchester              4392.0                     NaN
# 130         Wise              5632.0                     NaN
# 131        Wythe              3982.0                     NaN
# 132         York             13184.0                     NaN
#
#                                  Secondary School Plan      Risk
# 0    2 days in-school (50% students) and 3 days vir...  Moderate
# 1                                         All virtual        Low
# 2                                          All Virtual       Low
# 3    2 days in-school (50% students) and 3 days vir...  Moderate
# 4    2 days in-school (50% students) and 3 days vir...      High
# ..                                                 ...       ...
# 128                                        All virtual       Low
# 129  2 days in-school (50% students) and 3 days vir...      High
# 130  2 days in-school (50% students) and 3 days vir...  Moderate
# 131                                        All virtual       Low
# 132                                        All Virtual       Low
#
# [132 rows x 5 columns]
