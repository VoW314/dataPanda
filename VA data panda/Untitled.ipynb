# %%
import json
import pandas as pd
import numpy as np

# %%
VAmap = json.load(open("files/VAmap.geojson", "r"))
VAmap
# Out:
# {'type': 'FeatureCollection',
#  'name': 'County_Border',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'id': 4,
#    'properties': {'OBJECTID': 4,
#     'NAME': 'FAIRFAX COUNTY',
#     'CREATED_USER': 'FairfaxCounty',
#     'CREATED_DATE': '2020/08/22 05:04:52.011+00',
#     'LAST_EDITED_USER': 'FairfaxCounty',
#     'LAST_EDITED_DATE': '2020/08/22 05:04:52.011+00',
#     'Shape__Area': 11339633683.9141,
#     'Shape__Length': 689948.165655033},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-77.3280146091383, 39.0575880589234],
#        [-77.3278531054462, 39.0575576200204],
#        [-77.327793199891, 39.0575597694475],
#        [-77.3276628251352, 39.0575639630284],
#        [-77.3276168695035, 39.0575744887449],
#        [-77.3275497640969, 39.0575861767497],
#        [-77.3275003546839, 39.0575925492881],
#        [-77.3274474690599, 39.0575961393007],
# ...
